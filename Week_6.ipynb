# %% [markdown]
# <a href="https://colab.research.google.com/github/shaaagri/iat481-wk6/blob/main/Week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1> <b>Image Dataset Analysis and Project Development with YOLO </b> </center> </h1>
#
# In this tutorial, we will see how image datasets with different types of tasks such as detection , segmentation etc. look like, and how they are labelled, specifically in YOLO format.
#
# Then, we will download one dataset to explore it and clean it if required.

# %% [markdown]
# ## **Classification**
#
# Image classification is the simplest and involves classifying an entire image into one of a set of predefined classes.
#
# The output of an image classifier is a single class label and a confidence score. Image classification is useful when you need to know only what class an image belongs to and don't need to know where objects of that class are located or what their exact shape is.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418606-adf35c62-2e11-405d-84c6-b84e7d013804.png" width="600">

# %% [markdown]
# Usually each image has a single object in it, which is its class> Following image shows CIFAR10 Dataset.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://datagen.tech/wp-content/uploads/2022/11/image1.png" width="600">

# %% [markdown]
# The dataset should be labelled by arranging them in the following folders heirarchy.
#
#               root/
#               |-- class1/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- class2/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- class3/
#               |   |-- img1.jpg
#               |   |-- img2.jpg
#               |   |-- ...
#               |
#               |-- ...
#
# In this folder structure, the root directory contains one subdirectory for each class in the dataset. Each subdirectory is named after the corresponding class and contains all the images for that class.
#
# For example:
#
#               cifar-10-/
#               |
#               |-- train/
#               |   |-- airplane/
#               |   |   |-- 10008_airplane.png
#               |   |   |-- 10009_airplane.png
#               |   |   |-- ...
#               |   |
#               |   |-- automobile/
#               |   |   |-- 1000_automobile.png
#               |   |   |-- 1001_automobile.png
#               |   |   |-- ...
#               |   |
#               |   |-- bird/
#               |   |   |-- 10014_bird.png
#               |   |   |-- 10015_bird.png
#               |   |   |-- ...
#               |   |
#               |   |-- ...
#               |
#               |-- test/
#               |   |-- airplane/
#               |   |   |-- 10_airplane.png
#               |   |   |-- 11_airplane.png
#               |   |   |-- ...
#               |   |
#               |   |-- automobile/
#               |   |   |-- 100_automobile.png
#               |   |   |-- 101_automobile.png
#               |   |   |-- ...
#               |   |
#               |   |-- bird/
#               |   |   |-- 1000_bird.png
#               |   |   |-- 1001_bird.png
#               |   |   |-- ...
#               |   |
#               |   |-- ...

# %% [markdown]
# ## **Object Detection**

# %% [markdown]
# Object detection is a task that involves identifying the location and class of objects in an image or video stream.
#
# The output of an object detector is a set of bounding boxes that enclose the objects in the image, along with class labels and confidence scores for each box.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418624-5785cb93-74c9-4541-9179-d5c6782d491a.png" width="600">

# %% [markdown]
# **Labelling format**
#
# In object detection tasks, various labeling formats are used to annotate images with information about the objects present. These formats typically include details about the object's class and location within the image. Here are some of the most common labeling formats:
#
# 1. COCO
# 2. YOLO
# 3. CSV
# 5. XML
# 6. PASCAL VOC
#
# We will be discussing only YOLO format, as you will be using YOLO framework for your project:
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#
#       class_id bbox_x_center bbox_y_center bbox_width bbox_height
# - Box coordinates must be normalized between 0 and 1
#
#
# An example:

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/91506361-c7965000-e886-11ea-8291-c72b98c25eec.jpg" width="600">

# %% [markdown]
# Corresponding label text file should look like:
#
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/112467037-d2568c00-8d66-11eb-8796-55402ac0d62f.png" width="600">

# %% [markdown]
# ## **Segmentation**

# %% [markdown]
# Instance segmentation goes a step further than object detection and involves identifying individual objects in an image and segmenting them from the rest of the image.
#
# The output of an instance segmentation model is a set of masks or contours that outline each object in the image, along with class labels and confidence scores for each object. Instance segmentation is useful when you need to know not only where objects are in an image, but also what their exact shape is.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418644-7df320b8-098d-47f1-85c5-26604d761286.png" width="600">

# %% [markdown]
# **Labelling format for YOLO**
#
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#   - class index: An integer representing the class of the object (e.g., 0 for person, 1 for car, etc.).
#   - bounding coordinates: The bounding coordinates around the mask area, normalized to be between 0 and 1.
#
#
#       <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>
#
#
# Here is an example of the YOLO dataset format for a single image with two objects made up of a 3-point segment and a 5-point segment.
#
#
#       0 0.681 0.485 0.670 0.487 0.676 0.487
#       1 0.504 0.000 0.501 0.004 0.498 0.004 0.493 0.010 0.492 0.0104

# %% [markdown]
# ## **Pose Estimation**
# Pose estimation is a task that involves identifying the location of specific points in an image, usually referred to as keypoints. The keypoints can represent various parts of the object such as joints, landmarks, or other distinctive features. The locations of the keypoints are usually represented as a set of 2D [x, y] or 3D [x, y, visible] coordinates.
#
# The output of a pose estimation model is a set of points that represent the keypoints on an object in the image, usually along with the confidence scores for each point. Pose estimation is a good choice when you need to identify specific parts of an object in a scene, and their location in relation to each other.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/243418616-9811ac0b-a4a7-452a-8aba-484ba32bb4a8.png" width="600">

# %% [markdown]
# **Labelling format for YOLO**
#
#
# - One .txt file with labels file per image
# - One row per object
# - Each row contains:
#   - Object class index: An integer representing the class of the object (e.g., 0 for person, 1 for car, etc.).
#   - Object center coordinates: The x and y coordinates of the center of the object, normalized to be between 0 and 1.
#   - Object width and height: The width and height of the object, normalized to be between 0 and 1.
#   - Object keypoint coordinates: The keypoints of the object, normalized to be between 0 and 1.
#
#
# Here is an example of the label format for pose estimation task:
#
# Format with Dim = 2
#
#       <class-index> <x> <y> <width> <height> <px1> <py1> <px2> <py2> ... <pxn> <pyn>
# Format with Dim = 3
#
#       <class-index> <x> <y> <width> <height> <px1> <py1> <p1-visibility> <px2> <py2> <p2-visibility> ... <pxn> <pyn> <p2-visibility>

# %% [markdown]
# ## FOLDERS HEIRARCHY

# %% [markdown]
#  We need to convert the dataset into a specific heirarchy of folders for all the tasks except for task of classification.
#
#
# The directories should be in the following format:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **COCO128 Dataset**
#
# This section aims to introduce you to COCO dataset frequently used in Artificial Intelligence (AI).It is a foundational dataset in AI, widely used for tasks like object detection, segmentation, and image captioning.
#
#
# It Contains over 330,000 images with more than 200,000 labeled across 80 object categories. Unique for its richly annotated images, including object segmentation.It is widely used in computer vision research and has been used to train and evaluate many state-of-the-art object detection and segmentation models.
#
# Link to full dataset: https://cocodataset.org/#home

# %% [markdown]
# We are going using coco128 dataset.This dataset contains the first 128 images of COCO train 2017. It is used as the tutorial dataset for YOLO.
#
# Download the dataset from:
# https://www.kaggle.com/datasets/ultralytics/coco128/data

# %% [markdown]
# ## Dataset Visualization

# %% [markdown]
# To draw bounding boxes on images we need to understand the labelling format used by this dataset. The labels for this dataset are stored in YOLO format. i.e.
#
#         class_id bbox_x_center bbox_y_center bbox_width bbox_height

# %% [markdown]
# The class_id is the numerical number assigned to different class labels as shown below:

# %%
class_labels = {
    0: "person",
    1: "bicycle",
    2: "car",
    3: "motorcycle",
    4: "airplane",
    5: "bus",
    6: "train",
    7: "truck",
    8: "boat",
    9: "traffic light",
    10: "fire hydrant",
    11: "stop sign",
    12: "parking meter",
    13: "bench",
    14: "bird",
    15: "cat",
    16: "dog",
    17: "horse",
    18: "sheep",
    19: "cow",
    20: "elephant",
    21: "bear",
    22: "zebra",
    23: "giraffe",
    24: "backpack",
    25: "umbrella",
    26: "handbag",
    27: "tie",
    28: "suitcase",
    29: "frisbee",
    30: "skis",
    31: "snowboard",
    32: "sports ball",
    33: "kite",
    34: "baseball bat",
    35: "baseball glove",
    36: "skateboard",
    37: "surfboard",
    38: "tennis racket",
    39: "bottle",
    40: "wine glass",
    41: "cup",
    42: "fork",
    43: "knife",
    44: "spoon",
    45: "bowl",
    46: "banana",
    47: "apple",
    48: "sandwich",
    49: "orange",
    50: "broccoli",
    51: "carrot",
    52: "hot dog",
    53: "pizza",
    54: "donut",
    55: "cake",
    56: "chair",
    57: "couch",
    58: "potted plant",
    59: "bed",
    60: "dining table",
    61: "toilet",
    62: "tv",
    63: "laptop",
    64: "mouse",
    65: "remote",
    66: "keyboard",
    67: "cell phone",
    68: "microwave",
    69: "oven",
    70: "toaster",
    71: "sink",
    72: "refrigerator",
    73: "book",
    74: "clock",
    75: "vase",
    76: "scissors",
    77: "teddy bear",
    78: "hair drier",
    79: "toothbrush"
}

# %% [markdown]
# The rest of the four values i.e.
#
#     0.479492 0.688771 0.955609 0.5955
#
# indidicate the location of the bounding box.
#
# These values are normalized, which should be converted to a format that can be used as coordinate values of rectangle function (of cv2).

# %% [markdown]
# First import the required libraries:

# %%
import cv2
import matplotlib.pyplot as plt
import random as random
import os

# %% [markdown]
# Set all the paths of the dataset:

# %%
# Set the path to the dataset
dataset_path = "/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128"

# Get the list of all images paths in the dataset
image_paths = [os.path.join(dataset_path, "images", image_name) for image_name in os.listdir(os.path.join(dataset_path, "images"))]

# Get the list of all labels paths in the dataset
label_paths = [os.path.join(dataset_path, "labels", label_name) for label_name in os.listdir(os.path.join(dataset_path, "labels"))]

print (image_paths)
# Out:
# ['/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000471.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000089.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000294.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000641.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000384.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000491.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000415.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000595.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000349.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000357.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000072.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000387.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000332.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000025.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000030.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000560.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000625.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000623.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000540.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000164.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000536.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000520.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000142.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000368.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000544.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000620.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000149.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000309.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000529.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000263.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000074.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000009.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000400.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000260.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000488.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000531.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000338.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000395.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000196.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000419.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000514.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000626.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000144.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000138.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000486.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000508.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000071.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000201.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000474.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000490.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000597.jpg', '/content/drive/MyDri ...

# %% [markdown]
# The funtion "draw_yolo_box", takes input an image path and its corresponding label path. Then, draws the bounding boxes and write the object's label in each box. Finally it displays the images

# %%
def draw_yolo_bbox(image_path, label_path):
    # Load image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    height, width, _ = image.shape

    # Read label file
    with open(label_path, 'r') as file:
        bboxes = file.readlines()

    # Draw each bbox
    for bbox in bboxes:
        class_id, x_center, y_center, bbox_width, bbox_height = [float(x) for x in bbox.split()]

        # Convert YOLO bbox format to rectangle coordinates
        x1 = int((x_center - bbox_width / 2) * width)
        y1 = int((y_center - bbox_height / 2) * height)
        x2 = int((x_center + bbox_width / 2) * width)
        y2 = int((y_center + bbox_height / 2) * height)

        # Draw rectangle
        cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
        # Put label (class_id) near the bbox
        label = class_labels[int(class_id)]
        cv2.putText(image, label, (x1, y1+20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
    # Display image
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %% [markdown]
# The function "print_random_images" takes in input the list of images' paths, a number defining how much images we want to print. So it randomly selects the images to display and calls "draw_yolo_bbox".

# %%
def print_random_images(photos: list, n: int = 5):
  for im in range(n):
        random_photo_path = random.choice(photos)
        name=random_photo_path.split('/')[-1].split('.')[0]
        label_path=dataset_path+"/labels/"+name+".txt"
        draw_yolo_bbox(random_photo_path ,label_path )

# %% [markdown]
# Now, finally calling the function to display 6 images randomly.

# %%
print_random_images(image_paths,n=6 )

# %% [markdown]
# ## Dataset Cleaning

# %% [markdown]
# Interestingly, we found out that this dataset is not clean. i.e. labels of some of the images are missing and there are extra labels. So, we need to find out the missing labels files and remove that from the labels folder. Also, we need to find out missing images, which we also need to remove from the images folder.

# %%
#we already have a list of images' paths and labels' path, stored in variables : image_paths and label_paths
print(image_paths)
print(label_paths)
# Out:
# ['/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000471.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000089.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000294.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000641.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000384.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000491.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000415.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000595.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000349.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000357.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000072.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000387.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000332.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000025.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000030.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000560.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000625.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000623.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000540.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000164.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000536.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000520.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000142.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000368.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000544.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000620.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000149.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000309.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000529.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000263.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000074.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000009.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000400.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000260.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000488.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000531.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000338.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000395.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000196.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000419.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000514.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000626.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000144.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000138.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000486.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000508.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000071.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000201.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000474.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000490.jpg', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000597.jpg', '/content/drive/MyDri ...
# ['/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000326.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000144.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000309.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000605.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000359.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000370.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000165.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000357.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000394.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000034.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000415.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000201.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000164.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000368.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000241.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000089.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000520.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000328.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000307.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000260.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000529.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000428.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000074.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000459.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000636.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000581.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000471.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000136.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000597.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000332.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000143.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000491.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000086.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000438.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000569.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000575.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000656.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000540.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000071.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000360.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000502.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000560.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000486.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000208.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000623.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000192.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000247.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000599.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000263.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000127.txt', '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/labels/000000000042.txt', '/content/drive/MyDri ...

# %% [markdown]
# Now, we make a list of only the names of images' files and labels' files.
#
# e.g.  only  000000000531 without the extension

# %%
# Get the list of filenames without extensions
image_files = {file.split("/")[-1].split(".")[0] for file in image_paths}
label_files = {file.split("/")[-1].split(".")[0] for file in label_paths}

print(image_files)
# Out:
# {'000000000428', '000000000326', '000000000061', '000000000064', '000000000072', '000000000502', '000000000415', '000000000144', '000000000471', '000000000201', '000000000650', '000000000315', '000000000263', '000000000436', '000000000540', '000000000192', '000000000241', '000000000110', '000000000520', '000000000562', '000000000459', '000000000283', '000000000322', '000000000294', '000000000370', '000000000450', '000000000544', '000000000309', '000000000321', '000000000036', '000000000641', '000000000490', '000000000595', '000000000049', '000000000136', '000000000387', '000000000438', '000000000089', '000000000581', '000000000510', '000000000142', '000000000397', '000000000623', '000000000081', '000000000486', '000000000531', '000000000589', '000000000151', '000000000643', '000000000597', '000000000349', '000000000074', '000000000328', '000000000446', '000000000009', '000000000154', '000000000395', '000000000092', '000000000575', '000000000360', '000000000113', '000000000078', '000000000404', '000000000034', '000000000431', '000000000419', '000000000109', '000000000257', '000000000260', '000000000529', '000000000612', '000000000599', '000000000443', '000000000133', '000000000071', '000000000307', '000000000196', '000000000357', '000000000077', '000000000400', '000000000164', '000000000491', '000000000514', '000000000250', '000000000569', '000000000030', '000000000025', '000000000472', '000000000165', '000000000149', '000000000127', '000000000636', '000000000389', '000000000382', '000000000590', '000000000332', '000000000626', '000000000629', '000000000620', '000000000384', '000000000042', '000000000634', '000000000338', '000000000560', '000000000605', '000000000508', '000000000394', '000000000564', '000000000086', '000000000138', '000000000536', '000000000542', '000000000312', '000000000308', '000000000368', '000000000208', '000000000488', '000000000584', '000000000625', '000000000572', '000000000474', '000000000194', '000000000073', '000000000532', '000000000359', '000000000094', '000000000247', '000000000143'}

# %%
# Find extra files in each folder
extra_images = image_files - label_files
extra_labels = label_files - image_files

# Output the results
print(f"Extra images (without corresponding labels): {extra_images}")
print(f"Extra labels (without corresponding images): {extra_labels}")
# Out:
# Extra images (without corresponding labels): {'000000000250', '000000000508'}
# Extra labels (without corresponding images): {'000000000656', '000000000659'}

# %%
for file in extra_images:
     os.remove(os.path.join(dataset_path,"images", file + '.jpg')) # or '.png' depending on your image format

for file in extra_labels:
     os.remove(os.path.join(dataset_path,"labels", file + '.txt'))

# %% [markdown]
# Now removing them from the dataset:

# %%
os.path.join(dataset_path,"images", file + '.jpg')
# Out:
# '/content/drive/MyDrive/IAT481/Wk6/Datasets/coco128/images/000000000659.jpg'

# %% [markdown]
# Check again if it worked:

# %%
# Get the list of all images paths in the dataset
image_paths = [os.path.join(dataset_path, "images", image_name) for image_name in os.listdir(os.path.join(dataset_path, "images"))]

# Get the list of all labels paths in the dataset
label_paths = [os.path.join(dataset_path, "labels", label_name) for label_name in os.listdir(os.path.join(dataset_path, "labels"))]

# Get the list of filenames without extensions
image_files = {file.split("/")[-1].split(".")[0] for file in image_paths}
label_files = {file.split("/")[-1].split(".")[0] for file in label_paths}
# Find extra files in each folder
extra_images = image_files - label_files
extra_labels = label_files - image_files

# Output the results
print(f"Extra images (without corresponding labels): {extra_images}")
print(f"Extra labels (without corresponding images): {extra_labels}")
# Out:
# Extra images (without corresponding labels): set()
# Extra labels (without corresponding images): set()

# %% [markdown]
# There are none! great!
